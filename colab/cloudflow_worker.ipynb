# %% [markdown]
# # 🚀 Cloudflow Remote GPU Worker (Tesla T4 10-bit HEVC NVENC + VMAF Benchmark)
#
# Connects free Google Colab T4 GPU to your Cloudflow instance at **https://lucidesh4-cloudflow.hf.space**.
#
# ### 📋 Instructions:
# 1. Ensure Hardware Accelerator is set to **T4 GPU** (`Runtime` ➔ `Change runtime type` ➔ `T4 GPU`).
# 2. Click the **▶ Run** button below.
# 3. Leave this tab running in the background. Cloudflow will automatically detect the GPU and you can trigger video compressions directly from Cloudflow!

# %%
# Install dependencies (with libvmaf + NVENC support) & download latest worker
# !which ffmpeg && ffmpeg -filters 2>&1 | grep -q libvmaf || (curl -fsSL https://github.com/BtbN/FFmpeg-Builds/releases/download/latest/ffmpeg-master-latest-linux64-gpl.tar.xz | tar -xJ --strip-components=2 -C /usr/local/bin/ --wildcards '*/bin/ffmpeg' '*/bin/ffprobe')
# !pip install -q requests gallery-dl
# !curl -fsSL -H "Cache-Control: no-cache" "https://raw.githubusercontent.com/lucidesh4-stack/Torrent-to-drive/main/colab/cloudflow_worker.py?ts=$(date +%s)" -o cloudflow_worker.py
# !python cloudflow_worker.py
